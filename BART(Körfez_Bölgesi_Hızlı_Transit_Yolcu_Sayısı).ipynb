# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import sqlite3
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from yellowbrick.cluster import KElbowVisualizer

from scipy.cluster.hierarchy import linkage
from scipy.cluster.hierarchy import dendrogram
from sklearn.cluster import AgglomerativeClustering

pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)
from termcolor import colored

import warnings
warnings.filterwarnings("ignore")

pd.set_option("display.max_columns",100)
pd.set_option("display.width",100)
pd.set_option('display.float_format', lambda x: '%.3f' % x)

from sklearn.decomposition import PCA

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from sklearn.metrics import r2_score, mean_squared_error

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential

# %%
df1 = pd.read_csv('date-hour-soo-dest-2016.csv')

# %%
df1.head()
# Out:
#   Origin Destination  Throughput             DateTime
# 0   12TH        12TH           1  2016-01-01 00:00:00
# 1   12TH        16TH           1  2016-01-01 00:00:00
# 2   12TH        24TH           4  2016-01-01 00:00:00
# 3   12TH        ASHB           4  2016-01-01 00:00:00
# 4   12TH        BALB           2  2016-01-01 00:00:00

# %%
df1.shape
# Out:
# (9971582, 4)

# %%
df1.describe()
# Out:
#        Throughput
# count 9971582.000
# mean       12.854
# std        33.533
# min         1.000
# 25%         2.000
# 50%         4.000
# 75%        10.000
# max      1325.000

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9971582 entries, 0 to 9971581
# Data columns (total 4 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   Origin       object
#  1   Destination  object
#  2   Throughput   int64
#  3   DateTime     object
# dtypes: int64(1), object(3)
# memory usage: 304.3+ MB

# %%
df1.isnull().sum()
# Out:
# Origin         0
# Destination    0
# Throughput     0
# DateTime       0
# dtype: int64

# %%
df2 = pd.read_csv('date-hour-soo-dest-2017.csv')

# %%
df2.isnull().sum()
# Out:
# Origin         0
# Destination    0
# Throughput     0
# DateTime       0
# dtype: int64

# %%
df2.head()
# Out:
#   Origin Destination  Throughput             DateTime
# 0   12TH        19TH           1  2017-01-01 00:00:00
# 1   12TH        24TH           2  2017-01-01 00:00:00
# 2   12TH        BAYF           1  2017-01-01 00:00:00
# 3   12TH        CIVC           5  2017-01-01 00:00:00
# 4   12TH        COLS           2  2017-01-01 00:00:00

# %%
df2.shape
# Out:
# (3313625, 4)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3313625 entries, 0 to 3313624
# Data columns (total 4 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   Origin       object
#  1   Destination  object
#  2   Throughput   int64
#  3   DateTime     object
# dtypes: int64(1), object(3)
# memory usage: 101.1+ MB

# %%
df2.describe()
# Out:
#        Throughput
# count 3313625.000
# mean       12.536
# std        33.456
# min         1.000
# 25%         2.000
# 50%         4.000
# 75%         9.000
# max      1826.000

# %%
df=pd.concat([df1,df2])
df.head()
# Out:
#   Origin Destination  Throughput             DateTime
# 0   12TH        12TH           1  2016-01-01 00:00:00
# 1   12TH        16TH           1  2016-01-01 00:00:00
# 2   12TH        24TH           4  2016-01-01 00:00:00
# 3   12TH        ASHB           4  2016-01-01 00:00:00
# 4   12TH        BALB           2  2016-01-01 00:00:00

# %%
df.shape
# Out:
# (13285207, 4)

# %%
df
# Out:
#         Origin Destination  Throughput             DateTime
# 0         12TH        12TH           1  2016-01-01 00:00:00
# 1         12TH        16TH           1  2016-01-01 00:00:00
# 2         12TH        24TH           4  2016-01-01 00:00:00
# 3         12TH        ASHB           4  2016-01-01 00:00:00
# 4         12TH        BALB           2  2016-01-01 00:00:00
# ...        ...         ...         ...                  ...
# 3313620   WSPR        MONT           1  2017-05-03 23:00:00
# 3313621   WSPR        NBRK           1  2017-05-03 23:00:00
# 3313622   WSPR        NCON           1  2017-05-03 23:00:00
# 3313623   WSPR        SANL           2  2017-05-03 23:00:00
# 3313624   WSPR        SHAY           4  2017-05-03 23:00:00
#
# [13285207 rows x 4 columns]

# %%
df3=pd.read_csv('station_info.csv')

# %%
df3.head()
# Out:
#   Abbreviation                                        Description                 Location  \
# 0         12TH  1245 Broadway, Oakland CA 94612<br />12th St. ...  -122.271450,37.803768,0
# 1         16TH  2000 Mission Street, San Francisco CA 94110<br...  -122.419694,37.765062,0
# 2         19TH  1900 Broadway, Oakland CA 94612<br />19th Stre...  -122.268602,37.808350,0
# 3         24TH  2800 Mission Street, San Francisco CA 94110<br...  -122.418143,37.752470,0
# 4         ASHB  3100 Adeline Street, Berkeley CA 94703<br />As...  -122.270062,37.852803,0
#
#                                   Name
# 0  12th St. Oakland City Center (12TH)
# 1              16th St. Mission (16TH)
# 2              19th St. Oakland (19TH)
# 3              24th St. Mission (24TH)
# 4                         Ashby (ASHB)

# %%
df.head()
# Out:
#   Origin Destination  Throughput             DateTime
# 0   12TH        12TH           1  2016-01-01 00:00:00
# 1   12TH        16TH           1  2016-01-01 00:00:00
# 2   12TH        24TH           4  2016-01-01 00:00:00
# 3   12TH        ASHB           4  2016-01-01 00:00:00
# 4   12TH        BALB           2  2016-01-01 00:00:00

# %%
df.describe(include='object').T
# Out:
#                 count unique                  top    freq
# Origin       13285207     46                 POWL  424161
# Destination  13285207     46                 POWL  415710
# DateTime     13285207  10962  2017-04-21 17:00:00    1847

# %%
### Feature Engineering

# %%
df["DateTime"] = pd.to_datetime(df["DateTime"])

# %%
df["Year"] = df["DateTime"].dt.year
df["Month"] = df["DateTime"].dt.month
df["Day"] = df["DateTime"].dt.day
df["MonthName"] = df["DateTime"].dt.month_name()
df["DayName"] = df["DateTime"].dt.day_name()
df["Hour"] =  df["DateTime"].dt.hour

# %%
sns.countplot(x=df["Year"]);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bacc9202066e> in <cell line: 1>()
# ----> 1 sns.countplot(x=df["Year"]);
#
# NameError: name 'sns' is not defined

# %%
sns.histplot(x=df["Year"]);

# %%
sns.histplot(x=df["MonthName"]);

# %%
sns.histplot(x=df["DayName"]);

# %%
sns.histplot(x=df["Hour"]);

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure()
plt.xticks(rotation=45)
sns.countplot(x=df["MonthName"]);

# %%
plt.figure()
plt.xticks(rotation=45)
sns.countplot(x=df["DayName"]);

# %%
plt.figure()
plt.xticks(rotation=45)
sns.countplot(x=df["Hour"]);

# %%
df["Origin"].value_counts().plot(kind="barh",orientation="horizontal",figsize=(10,6),fontsize=9,title="Counts For Each Station As destination",alpha=.99);

# %%
df.loc[df["Year"]==2016,"Hour"].value_counts().sort_values().plot(kind="bar",ylabel="Counts",xlabel="In Hour",
                                title="Count Intensity In 2016",figsize=(8,5),xlim=(0,1000000),alpha=.9);

# %%
plt.figure(figsize=(8,4))
df.loc[(df["route"]=="DBRK--->SFIA") | (df["route"]=="NBRK--->SFIA")].groupby("Day_name")['Throughput'].apply(sum).sort_values(ascending=True).plot.bar()

# %%
df["longitude"] = df["Location"].apply(lambda x: float(x.split(",")[0]))
df["latitude"] = df["Location"].apply(lambda x: float(x.split(",")[1]))

# %%
df.drop("Location", axis=1, inplace=True)

# %%
df["Route"] = df["Origin"]+"-"+df["Destination"]

# %%
df=pd.merge(df,df3,left_on='Origin',right_on='Abbreviation')

# %%
df.info()

# %%
df.drop(["Abbreviation_x","Abbreviation_y"],axis=1,inplace=True)

# %%
df_model=data.groupby("route")["Throughput"].aggregate(sum)

# %%
df_model.head()

# %%
df.isnull().sum()

# %%
x=df.drop("Throughput",axis=1)
y=df["Throughput"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=.2,shuffle=True)

# %%
print(x_train.shape,y_train.shape)
print(x_test.shape,y_test.shape)

# %%
model=Sequential()
model.add(Dense(32,activation="relu"))
model.add(Dense(9,activation="relu"))
model.add(Dense(4))
model.compile(loss="mse",optimizer="adam")

# %%
model.summary()

# %%
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), batch_size=32, epochs=10)

# %%
tahmin = model.predict(X_test)

# %%
plt.plot(history.history["loss"], label="LOSS")
plt.plot(history.history["val_loss"], label="VALIDATION LOSS")
plt.legend();

# %%
tahmin

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Assuming 'x' and 'y' are your original data
# Replace 'your_dataframe' with the actual name of your DataFrame
x = pd.DataFrame(x)  # Convert x to a DataFrame if it's not already

# Check for non-numeric values in 'x'
print(x[x.applymap(lambda x: isinstance(x, str)).any(axis=1)])

# Replace or remove non-numeric values in 'x'
# Example: Replace 'SANL' with NaN and then fill NaNs with 0
x = x.replace('SANL', pd.NA).fillna(0)

# Convert 'x' to numeric type
x = x.astype(float)

# Split the data
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=42, test_size=.2, shuffle=True)

# Define the model
model = Sequential()
model.add(Dense(32, activation="relu"))
model.add(Dense(9, activation="relu"))
model.add(Dense(4))
model.compile(loss="mse", optimizer="adam")

# Train the model
history = model.fit(x_train, y_train, validation_data=(x_test, y_test), batch_size=32, epochs=10)
